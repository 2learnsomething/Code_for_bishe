# %%
! pip install numpy
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting numpy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/40/ed/c9d2760a6ca8e76984766221cb68441e83fc590c640aeb4140c22ead488e/numpy-1.22.1-cp39-cp39-win_amd64.whl (14.7 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.22.1

# %%
! pip install pandas
! pip install matplotlib
! pip install torch torchvision torchaudio
! pip install tensorflow
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting pandas
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/53/1a/1a2c484259c16ec132c4b3694a59b9562609b6955e3f9a7dad8af066a021/pandas-1.4.0-cp39-cp39-win_amd64.whl (10.5 MB)
# Requirement already satisfied: numpy>=1.18.5 in d:\anaconda3\envs\bishe\lib\site-packages (from pandas) (1.22.1)
# Collecting pytz>=2020.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/d3/e3/d9f046b5d1c94a3aeab15f1f867aa414f8ee9d196fae6865f1d6a0ee1a0b/pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda3\envs\bishe\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\bishe\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.4.0 pytz-2021.3
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting matplotlib
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/86/cd/619a45613393293117297f2f0e5086a619e1ea98c5e2ce6d0f554ddc97c3/matplotlib-3.5.1-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting cycler>=0.10
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/5c/f9/695d6bedebd747e5eb0fe8fad57b72fdf25411273a39791cde838d5a8f51/cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting packaging>=20.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/05/8e/8de486cbd03baba4deef4142bd643a3e7bbe954a784dc1bb17142572d127/packaging-21.3-py3-none-any.whl (40 kB)
# Collecting fonttools>=4.22.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1b/1e/23df4eda86938b503698c24f100462f6e80a8b40094635284e57994722ac/fonttools-4.29.0-py3-none-any.whl (895 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/04/9d/4ccf8ad52441787ed4ae97132f62dc52ce6556406d4b5a7128f00a15511d/kiwisolver-1.3.2-cp39-cp39-win_amd64.whl (52 kB)
# Collecting pillow>=6.2.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/ed/27/b5186d773e4c341c876f9f5ce1b13bdbb02b78f5793d9370d237014cf029/Pillow-9.0.0-cp39-cp39-win_amd64.whl (3.2 MB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib) (1.22.1)
# Collecting pyparsing>=2.2.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/80/c1/23fd82ad3121656b585351aba6c19761926bb0db2ebed9e4ff09a43a3fcc/pyparsing-3.0.7-py3-none-any.whl (98 kB)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\bishe\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, packaging, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.29.0 kiwisolver-1.3.2 matplotlib-3.5.1 packaging-21.3 pillow-9.0.0 pyparsing-3.0.7
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting torch
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/82/49/cb675c5b70a081f39a2b09d0b4d98a2b14f08d895b3439fe3c0c48163018/torch-1.10.2-cp39-cp39-win_amd64.whl (226.5 MB)
# Collecting torchvision
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/8b/68/5a976d601c11f527cb278dbd510521e3d6e192d7c5fd60471e64d1c84c25/torchvision-0.11.3-cp39-cp39-win_amd64.whl (947 kB)
# Collecting torchaudio
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d0/c9/8fcdb83e97fd43b1946ef04a99e3968c3e26d9a4249670c2f609051eac46/torchaudio-0.10.2-cp39-cp39-win_amd64.whl (341 kB)
# Requirement already satisfied: typing-extensions in d:\anaconda3\envs\bishe\lib\site-packages (from torch) (4.0.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in d:\anaconda3\envs\bishe\lib\site-packages (from torchvision) (9.0.0)
# Requirement already satisfied: numpy in d:\anaconda3\envs\bishe\lib\site-packages (from torchvision) (1.22.1)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.2 torchaudio-0.10.2 torchvision-0.11.3
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting tensorflow
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/9c/6f/1c4b47af8a8b208fc7fc427fd5913f07ed7cc8488ad99ce499536f7db03f/tensorflow-2.7.0-cp39-cp39-win_amd64.whl (430.8 MB)
# Collecting h5py>=2.9.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/aa/f4/ac94dab6d8178858a59e4faed0dc421efc02d347d09cf3e6ae55507e0cb4/h5py-3.6.0-cp39-cp39-win_amd64.whl (2.8 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a4/05/f198d4fed3e659759068cc91a4260421c717bf25ea06d488cd2dedfc6684/grpcio-1.43.0-cp39-cp39-win_amd64.whl (3.4 MB)
# Collecting google-pasta>=0.1.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting flatbuffers<3.0,>=1.12
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3d/d0/26033c70d642fbc1e35d3619cf3210986fb953c173b1226709f75056c149/flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda3\envs\bishe\lib\site-packages (from tensorflow) (1.16.0)
# Collecting keras<2.8,>=2.7.0rc0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/6b/8b/065f94ba03282fa41b2d76942b87a180a9913312c4611ea7d6508fbbc114/keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# Collecting astunparse>=1.6.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorboard~=2.6
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/f7/fd/67c61276de025801cfa8a1b9af2d7c577e7f27c17b6bff2baca20bf03543/tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Collecting wrapt>=1.11.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/00/ae/e8e88651721412ce1e981300a70aaaf88197149682ddd6a890e03ab49b25/wrapt-1.13.3-cp39-cp39-win_amd64.whl (34 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda3\envs\bishe\lib\site-packages (from tensorflow) (4.0.1)
# Collecting keras-preprocessing>=1.1.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/5c/e8/2f24a107a951cb5f36b9ea4c97b3f5cd4ba942ea38ea4e7380915d8a8280/tensorflow_io_gcs_filesystem-0.23.1-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting absl-py>=0.4.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/2c/03/e3e19d3faf430ede32e41221b294e37952e06acc96781c417ac25d4a0324/absl_py-1.0.0-py3-none-any.whl (126 kB)
# Collecting libclang>=9.0.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/fa/09/98786c8eaae694c63a9305667d4e60faec3d5a3b7c32fdd30ce02c470cab/libclang-13.0.0-py2.py3-none-win_amd64.whl (13.9 MB)
# Requirement already satisfied: numpy>=1.14.5 in d:\anaconda3\envs\bishe\lib\site-packages (from tensorflow) (1.22.1)
# Collecting protobuf>=3.9.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ef/09/d36ab17b165f3bd942c44c025a19d92d20b25ef550c457d1fe8a65b71fa7/protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# Collecting gast<0.5.0,>=0.2.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/b6/48/583c032b79ae5b3daa02225a675aeb673e58d2cb698e78510feceb11958c/gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/db/de/3a71ad41b87f9dd424e3aec3b0794a60f169fa7e9a9a1e3dd44290b86dd6/tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in d:\anaconda3\envs\bishe\lib\site-packages (from tensorflow) (0.37.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ed/c8/24b2007dacaa0d4255df62485a92363288eec962deb2dafcc046a5b17aae/google_auth-2.5.0-py2.py3-none-any.whl (157 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/e0/68/e8ecfac5dd594b676c23a7f07ea34c197d7d69b3313afdf8ac1b0a9905a2/tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting requests<3,>=2.21.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/2d/61/08076519c80041bc0ffa1a8af0cbd3bf3e2b62af10435d269a9d0f40564d/requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/74/69/5747a957f95e2e1d252ca41476ae40ce79d70d38151d2e494feb7722860c/tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/b1/0e/0636cc1448a7abc444fb1b3a63655e294e0d2d49092dc3de05241be6d43c/google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=0.11.15
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/1e/73/51137805d1b8d97367a8a77cae4a792af14bb7ce58fbd071af294c740cf0/Werkzeug-2.0.2-py3-none-any.whl (288 kB)
# Requirement already satisfied: setuptools>=41.0.0 in d:\anaconda3\envs\bishe\lib\site-packages (from tensorboard~=2.6->tensorflow) (60.5.0)
# Collecting markdown>=2.6.8
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/9f/d4/2c7f83915d437736996b2674300c6c4b578a6f897f34e40f5c04db146719/Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/19/99/ace1769546388976b45e93445bb04c6df95e96363f03fbb56f916da5ebde/cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/30/ab/8fd9e88e6fa5ec41afca995938bbefb72195278e0cfc5bd76a4f29b23fb2/rsa-4.8-py3-none-any.whl (39 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6f/bb/5deac77a9af870143c684ab46a7934038a53eb4aa975bc0687ed6ca2c610/requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/58/fd/f82049e9b21773188a72bd1bc53530b900392808f8b823e4c778e7c035f0/importlib_metadata-4.10.1-py3-none-any.whl (17 kB)
# Collecting charset-normalizer~=2.0.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/84/3e/1037abe6498e65d645ce7a22d3402605d49a3b2c7f20c3abb027760da4f0/charset_normalizer-2.0.10-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/4e/b8/f5a25b22e803f0578e668daa33ba3701bb37858ec80e08a150bd7d2cf1b1/urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
# Collecting certifi>=2017.4.17
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/37/45/946c02767aabb873146011e665728b680884cd8fe70dde973c640e45b775/certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting idna<4,>=2.5
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/04/a2/d918dcd22354d8958fe113e1a3630137e0fc8b44859ade3063982eacd2a4/idna-3.3-py3-none-any.whl (61 kB)
# Collecting zipp>=0.5
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/52/c5/df7953fe6065185af5956265e3b16f13c2826c2b1ba23d43154f3af453bc/zipp-3.7.0-py3-none-any.whl (5.3 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1d/46/5ee2475e1b46a26ca0fa10d3c1d479577fde6ee289f8c6aa6d7ec33e31fd/oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Installing collected packages: urllib3, pyasn1, idna, charset-normalizer, certifi, zipp, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-5.0.0 certifi-2021.10.8 charset-normalizer-2.0.10 flatbuffers-2.0 gast-0.4.0 google-auth-2.5.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.43.0 h5py-3.6.0 idna-3.3 importlib-metadata-4.10.1 keras-2.7.0 keras-preprocessing-1.1.2 libclang-13.0.0 markdown-3.3.6 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.23.1 termcolor-1.1.0 urllib3-1.26.8 werkzeug-2.0.2 wrapt-1.13.3 zipp-3.7.0

# %%
! pip install openpyxl
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting openpyxl
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/1c/a6/8ce4d2ef2c29be3235c08bb00e0b81e29d38ebc47d82b17af681bf662b74/openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
# Collecting et-xmlfile
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9

# %%
! pip install tushare
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting tushare
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d5/27/25bee559f82e02b96005d8d0845f72eaa56d7d2e63cc9474d7572d2bf0e1/tushare-1.2.83-py3-none-any.whl (130 kB)
# Collecting websocket-client==0.57.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting simplejson
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/99/c1/b0a72b566466b67b15a26561269e65f6a730cbd6c33f9f06f2a0c66dbeb4/simplejson-3.17.6-cp39-cp39-win_amd64.whl (75 kB)
# Requirement already satisfied: requests in d:\anaconda3\envs\bishe\lib\site-packages (from tushare) (2.27.1)
# Requirement already satisfied: pandas in d:\anaconda3\envs\bishe\lib\site-packages (from tushare) (1.4.0)
# Collecting bs4
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting lxml
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/f0/8f/6c6eaacdbb85b4c032a93967c9a4850d4e9318e6ee151ed4bc544739c57d/lxml-4.7.1-cp39-cp39-win_amd64.whl (3.7 MB)
# Requirement already satisfied: six in d:\anaconda3\envs\bishe\lib\site-packages (from websocket-client==0.57.0->tushare) (1.16.0)
# Collecting beautifulsoup4
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/69/bf/f0f194d3379d3f3347478bd267f754fc68c11cbf2fe302a6ab69447b1417/beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda3\envs\bishe\lib\site-packages (from pandas->tushare) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\bishe\lib\site-packages (from pandas->tushare) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in d:\anaconda3\envs\bishe\lib\site-packages (from pandas->tushare) (1.22.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\bishe\lib\site-packages (from requests->tushare) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\envs\bishe\lib\site-packages (from requests->tushare) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\bishe\lib\site-packages (from requests->tushare) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\envs\bishe\lib\site-packages (from requests->tushare) (2.0.10)
# Collecting soupsieve>1.2
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/72/a6/fd01694427f1c3fcadfdc5f1de901b813b9ac756f0806ef470cfed1de281/soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=90d05c2fac59784337b9296b0863d7066932320b3487fbb2577423e81107a8cf
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\02\37\2a\d32b991c0064f63108da01a9163a54ab4a8f273427315a6092
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, websocket-client, simplejson, lxml, bs4, tushare
# Successfully installed beautifulsoup4-4.10.0 bs4-0.0.1 lxml-4.7.1 simplejson-3.17.6 soupsieve-2.3.1 tushare-1.2.83 websocket-client-0.57.0

# %%
! pip install mplfinance
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting mplfinance
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/01/dc/d4b4d27aa1e67da9ac3736f8a132f7474b4b889f2b8ed3a17073f5e6bfe0/mplfinance-0.12.8b9-py3-none-any.whl (70 kB)
# Requirement already satisfied: matplotlib in d:\anaconda3\envs\bishe\lib\site-packages (from mplfinance) (3.5.1)
# Requirement already satisfied: pandas in d:\anaconda3\envs\bishe\lib\site-packages (from mplfinance) (1.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->mplfinance) (4.29.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->mplfinance) (1.22.1)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->mplfinance) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->mplfinance) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->mplfinance) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\bishe\lib\site-packages (from pandas->mplfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\bishe\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.8b9

# %%
! pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# absl-py                       1.0.0
# asttokens                     2.0.5
# astunparse                    1.6.3
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.10.0
# black                         21.12b0
# bs4                           0.0.1
# cachetools                    5.0.0
# certifi                       2021.10.8
# charset-normalizer            2.0.10
# click                         8.0.3
# colorama                      0.4.4
# cycler                        0.11.0
# dataclasses                   0.8
# debugpy                       1.5.1
# decorator                     5.1.1
# entrypoints                   0.3
# et-xmlfile                    1.1.0
# executing                     0.8.2
# flatbuffers                   2.0
# fonttools                     4.29.0
# gast                          0.4.0
# google-auth                   2.5.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# grpcio                        1.43.0
# h5py                          3.6.0
# idna                          3.3
# importlib-metadata            4.10.1
# ipykernel                     6.7.0
# ipython                       8.0.1
# jedi                          0.18.1
# jupyter-client                7.1.2
# jupyter-core                  4.9.1
# keras                         2.7.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.2
# libclang                      13.0.0
# lxml                          4.7.1
# Markdown                      3.3.6
# matplotlib                    3.5.1
# matplotlib-inline             0.1.3
# mplfinance                    0.12.8b9
# mypy-extensions               0.4.3
# nest-asyncio                  1.5.4
# numpy                         1.22.1
# oauthlib                      3.2.0
# openpyxl                      3.0.9
# opt-einsum                    3.3.0
# packaging                     21.3
# pandas                        1.4.0
# parso                         0.8.3
# pathspec                      0.9.0
# pickleshare                   0.7.5
# Pillow                        9.0.0
# pip                           21.3.1
# platformdirs                  2.3.0
# prompt-toolkit                3.0.26
# protobuf                      3.19.4
# pure-eval                     0.2.2
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# Pygments                      2.11.2
# pyparsing                     3.0.7
# python-dateutil               2.8.2
# pytz                          2021.3
# pywin32                       303
# pyzmq                         22.3.0
# requests                      2.27.1
# requests-oauthlib             1.3.1
# rsa                           4.8
# setuptools                    60.5.0
# simplejson                    3.17.6
# six                           1.16.0
# soupsieve                     2.3.1
# stack-data                    0.1.4
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.7.0
# tensorflow-estimator          2.7.0
# tensorflow-io-gcs-filesystem  0.23.1
# termcolor                     1.1.0
# tomli                         1.2.2
# torch                         1.10.2
# torchaudio                    0.10.2
# torchvision                   0.11.3
# tornado                       6.1
# traitlets                     5.1.1
# tushare                       1.2.83
# typed-ast                     1.5.2
# typing_extensions             4.0.1
# urllib3                       1.26.8
# wcwidth                       0.2.5
# websocket-client              0.57.0
# Werkzeug                      2.0.2
# wheel                         0.37.1
# wrapt                         1.13.3
# yapf                          0.32.0
# zipp                          3.7.0

# %%
! pip install nltk
! pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.tuna.tsinghua.edu.cn', port=443): Read timed out. (read timeout=15)")': /simple/nltk/
# Collecting nltk
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/c5/ea/84c7247f5c96c5a1b619fe822fb44052081ccfbe487a49d4c888306adec7/nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Collecting regex>=2021.8.3
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/14/57/ecd4833927de1a53c0fd68021c0d4e73d479c5092287c9c5e2ff661c2c41/regex-2022.1.18-cp39-cp39-win_amd64.whl (273 kB)
# Collecting joblib
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3e/d5/0163eb0cfa0b673aa4fe1cd3ea9d8a81ea0f32e50807b0c295871e4aab2e/joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Requirement already satisfied: click in d:\anaconda3\envs\bishe\lib\site-packages (from nltk) (8.0.3)
# Collecting tqdm
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/63/f3/b7a1b8e40fd1bd049a34566eb353527bb9b8e9b98f8b6cf803bb64d8ce95/tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Requirement already satisfied: colorama in d:\anaconda3\envs\bishe\lib\site-packages (from click->nltk) (0.4.4)
# Installing collected packages: tqdm, regex, joblib, nltk
# Successfully installed joblib-1.1.0 nltk-3.6.7 regex-2022.1.18 tqdm-4.62.3
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting scikit-learn
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/0b/5f/f9a191519f6daf2c268256511c38e0cf638ff8e308bcadaf96a69e3e85af/scikit_learn-1.0.2-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: numpy>=1.14.6 in d:\anaconda3\envs\bishe\lib\site-packages (from scikit-learn) (1.22.1)
# Collecting scipy>=1.1.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/5d/43/79af04bf5eef99cedb068148a1a0bb04567d958c872c85b02c8bc65021e7/scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "D:\Anaconda3\envs\bishe\lib\http\client.py", line 463, in read
#     n = self.readinto(b)
#   File "D:\Anaconda3\envs\bishe\lib\http\client.py", line 507, in readinto
#     n = self.fp.readinto(b)
#   File "D:\Anaconda3\envs\bishe\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "D:\Anaconda3\envs\bishe\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\Anaconda3\envs\bishe\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\cli\base_command.py", line 164, in exc_logging_wrapper
#     status = run_func(*args)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\cli\req_command.py", line 205, in wrapper
#     return func(self, options, args)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\commands\install.py", line 338, in run
#     requirement_set = resolver.resolve(
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 482, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 374, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 214, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 205, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _add_to_criteria
#     if not criterion.candidates:
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 201, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 281, in __init__
#     super().__init__(
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 292, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\operations\prepare.py", line 482, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\operations\prepare.py", line 527, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\operations\prepare.py", line 213, in unpack_url
#     file = get_http_url(
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\operations\prepare.py", line 94, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\network\download.py", line 145, in __call__
#     for chunk in chunks:
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\cli\progress_bars.py", line 144, in iter
#     for x in it:
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "D:\Anaconda3\envs\bishe\lib\contextlib.py", line 137, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "D:\Anaconda3\envs\bishe\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='pypi.tuna.tsinghua.edu.cn', port=443): Read timed out.

# %%
! pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting scikit-learn
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/0b/5f/f9a191519f6daf2c268256511c38e0cf638ff8e308bcadaf96a69e3e85af/scikit_learn-1.0.2-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: numpy>=1.14.6 in d:\anaconda3\envs\bishe\lib\site-packages (from scikit-learn) (1.22.1)
# Collecting threadpoolctl>=2.0.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/61/cf/6e354304bcb9c6413c4e02a747b600061c21d38ba51e7e544ac7bc66aecc/threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.1.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/5d/43/79af04bf5eef99cedb068148a1a0bb04567d958c872c85b02c8bc65021e7/scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda3\envs\bishe\lib\site-packages (from scikit-learn) (1.1.0)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.0.2 scipy-1.8.0 threadpoolctl-3.1.0

# %%
! pip install jieba
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting jieba
#   Using cached jieba-0.42.1-py3-none-any.whl
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %%
! pip install -i https://pypi.tuna.tsinghua.edu.cn/simple wordcloud
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting wordcloud
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/be/33/5bdd39587f0e8ede3fe12d9d16d6f1fb5e7a43f29621604a949ee362d013/wordcloud-1.8.1.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.1 in d:\anaconda3\envs\bishe\lib\site-packages (from wordcloud) (1.22.1)
# Requirement already satisfied: pillow in d:\anaconda3\envs\bishe\lib\site-packages (from wordcloud) (9.0.0)
# Requirement already satisfied: matplotlib in d:\anaconda3\envs\bishe\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->wordcloud) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->wordcloud) (4.29.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\bishe\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\bishe\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py): started
#   Building wheel for wordcloud (setup.py): finished with status 'error'
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# Installing collected packages: wordcloud
#     Running setup.py install for wordcloud: started
#     Running setup.py install for wordcloud: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Anaconda3\envs\bishe\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-xfoewpmd\\wordcloud_9bd20c020a1842b09b3353a1df67deac\\setup.py'"'"'; __file__='"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-xfoewpmd\\wordcloud_9bd20c020a1842b09b3353a1df67deac\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Lenovo\AppData\Local\Temp\pip-wheel-9254_1y9'
#        cwd: C:\Users\Lenovo\AppData\Local\Temp\pip-install-xfoewpmd\wordcloud_9bd20c020a1842b09b3353a1df67deac\
#   Complete output (65 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#   UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#   set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#   running build_ext
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Lenovo\AppData\Local\Temp\pip-install-xfoewpmd\wordcloud_9bd20c020a1842b09b3353a1df67deac\setup.py", line 9, in <module>
#       setup(
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\__init__.py", line 155, in setup
#       return distutils.core.setup(**attrs)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#       return run_commands(dist)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#       dist.run_commands()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#       self.run_command(cmd)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\command\build_ext.py", line 79, in run
#       _build_ext.run(self)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 339, in run
#       self.build_extensions()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 448, in build_extensions
#       self._build_extensions_serial()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 473, in _build_extensions_serial
#       self.build_extension(ext)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\command\build_ext.py", line 202, in build_extension
#       _build_ext.build_extension(self, ext)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 528, in build_extension
#       objects = self.compiler.compile(sources,
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 327, in compile
#       self.initialize()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 224, in initialize
#       vc_env = _get_vc_env(plat_spec)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\msvc.py", line 316, in msvc14_get_vc_env
#       return _msvc14_get_vc_env(plat_spec)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\msvc.py", line 270, in _msvc14_get_vc_env
#       raise distutils.errors.DistutilsPlatformError(
#   setuptools._distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for wordcloud
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Anaconda3\envs\bishe\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-xfoewpmd\\wordcloud_9bd20c020a1842b09b3353a1df67deac\\setup.py'"'"'; __file__='"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-xfoewpmd\\wordcloud_9bd20c020a1842b09b3353a1df67deac\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Lenovo\AppData\Local\Temp\pip-record-4_1x0u47\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\Anaconda3\envs\bishe\Include\wordcloud'
#          cwd: C:\Users\Lenovo\AppData\Local\Temp\pip-install-xfoewpmd\wordcloud_9bd20c020a1842b09b3353a1df67deac\
#     Complete output (21 lines):
#     running install
#     D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#     UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#     set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#     running build_ext
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'D:\Anaconda3\envs\bishe\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-xfoewpmd\\wordcloud_9bd20c020a1842b09b3353a1df67deac\\setup.py'"'"'; __file__='"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-xfoewpmd\\wordcloud_9bd20c020a1842b09b3353a1df67deac\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Lenovo\AppData\Local\Temp\pip-record-4_1x0u47\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\Anaconda3\envs\bishe\Include\wordcloud' Check the logs for full command output.

# %%
! pip install zhon
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting zhon
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9f/b0/c56c6079ad47c35a2341440818b6620de8c46a265ed690a51b1a4e5591bc/zhon-1.1.5.tar.gz (99 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: zhon
#   Building wheel for zhon (setup.py): started
#   Building wheel for zhon (setup.py): finished with status 'done'
#   Created wheel for zhon: filename=zhon-1.1.5-py3-none-any.whl size=84322 sha256=2a880c62e0341fe4eeeadd487f68b0c9529ec1735df6fa7b5e54f6f61ecf57c4
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\51\97\8b\cc34b5b6cc05a2370310945201f8f5b3566da82fb8e95d4680
# Successfully built zhon
# Installing collected packages: zhon
# Successfully installed zhon-1.1.5

# %%
# 旧版本升级
! pip install jieba --upgrade
# 使用paddle模式：结巴版本大于0.4且安装paddlepaddle-tiny模块
! pip install paddlepaddle-tiny
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: jieba in d:\anaconda3\envs\bishe\lib\site-packages (0.42.1)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ERROR: Could not find a version that satisfies the requirement paddlepaddle-tiny (from versions: none)
# ERROR: No matching distribution found for paddlepaddle-tiny

# %%
! pip install paddlepaddle-tiny==1.6.1
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: paddlepaddle-tiny==1.6.1 in d:\anaconda3\envs\bishe\lib\site-packages (1.6.1)
# Collecting graphviz
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9d/fb/886e8ec7862989afc0c35d15813b6c665fe134cc6027cdde2fa300abe9a2/graphviz-0.19.1-py3-none-any.whl (46 kB)
# Requirement already satisfied: numpy>=1.12 in d:\anaconda3\envs\bishe\lib\site-packages (from paddlepaddle-tiny==1.6.1) (1.22.1)
# Requirement already satisfied: decorator in d:\anaconda3\envs\bishe\lib\site-packages (from paddlepaddle-tiny==1.6.1) (5.1.1)
# Requirement already satisfied: protobuf>=3.1.0 in d:\anaconda3\envs\bishe\lib\site-packages (from paddlepaddle-tiny==1.6.1) (3.19.4)
# Requirement already satisfied: six in d:\anaconda3\envs\bishe\lib\site-packages (from paddlepaddle-tiny==1.6.1) (1.16.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda3\envs\bishe\lib\site-packages (from paddlepaddle-tiny==1.6.1) (2.27.1)
# Collecting objgraph
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a9/79/9f47706447b9ba0003c0680da4fed1d502adf410e1d953b4d1a5d3486640/objgraph-3.5.0-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\envs\bishe\lib\site-packages (from requests>=2.0.0->paddlepaddle-tiny==1.6.1) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\bishe\lib\site-packages (from requests>=2.0.0->paddlepaddle-tiny==1.6.1) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\envs\bishe\lib\site-packages (from requests>=2.0.0->paddlepaddle-tiny==1.6.1) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\bishe\lib\site-packages (from requests>=2.0.0->paddlepaddle-tiny==1.6.1) (2021.10.8)
# Installing collected packages: graphviz, objgraph
# Successfully installed graphviz-0.19.1 objgraph-3.5.0

# %%
! pip install pmdarima
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting pmdarima
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/30/bd/f7e17f4f84ec683dab0d450a7ac8226d6d00c5772987270501a0e047970b/pmdarima-1.8.4-cp39-cp39-win_amd64.whl (600 kB)
# Requirement already satisfied: scipy>=1.3.2 in d:\anaconda3\envs\bishe\lib\site-packages (from pmdarima) (1.8.0)
# Requirement already satisfied: urllib3 in d:\anaconda3\envs\bishe\lib\site-packages (from pmdarima) (1.26.8)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\anaconda3\envs\bishe\lib\site-packages (from pmdarima) (60.5.0)
# Requirement already satisfied: pandas>=0.19 in d:\anaconda3\envs\bishe\lib\site-packages (from pmdarima) (1.4.0)
# Collecting Cython!=0.29.18,>=0.29
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9f/79/311cfbca90332ab37ef8ea08f1af3266f20a9a0e7a1d652842db832226bb/Cython-0.29.28-py2.py3-none-any.whl (983 kB)
# Requirement already satisfied: scikit-learn>=0.22 in d:\anaconda3\envs\bishe\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: numpy>=1.19.3 in d:\anaconda3\envs\bishe\lib\site-packages (from pmdarima) (1.22.1)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda3\envs\bishe\lib\site-packages (from pmdarima) (1.1.0)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c3/73/fec9fad97b97e879338f1e30fd1717d7a802ce702df8837649349440f2e6/statsmodels-0.13.2-cp39-cp39-win_amd64.whl (9.1 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda3\envs\bishe\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\bishe\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda3\envs\bishe\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda3\envs\bishe\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Collecting patsy>=0.5.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/87/7f/d37cd027c25145eeba92b1a756976931c831803d92547c8637a3400c339f/patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\bishe\lib\site-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.7)
# Requirement already satisfied: six in d:\anaconda3\envs\bishe\lib\site-packages (from patsy>=0.5.2->statsmodels!=0.12.0,>=0.11->pmdarima) (1.16.0)
# Installing collected packages: patsy, statsmodels, Cython, pmdarima
# Successfully installed Cython-0.29.28 patsy-0.5.2 pmdarima-1.8.4 statsmodels-0.13.2

# %%
! pip install pkuseg
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting pkuseg
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/64/3a/090a533c7f0682d653633cfd2d33e9aab3e671379fb199aeb7fa9bd3c34a/pkuseg-0.0.25.tar.gz (48.8 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cython in d:\anaconda3\envs\bishe\lib\site-packages (from pkuseg) (0.29.28)
# Requirement already satisfied: numpy>=1.16.0 in d:\anaconda3\envs\bishe\lib\site-packages (from pkuseg) (1.22.1)
# Building wheels for collected packages: pkuseg
#   Building wheel for pkuseg (setup.py): started
#   Building wheel for pkuseg (setup.py): finished with status 'error'
#   Running setup.py clean for pkuseg
# Failed to build pkuseg
# Installing collected packages: pkuseg
#     Running setup.py install for pkuseg: started
#     Running setup.py install for pkuseg: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Anaconda3\envs\bishe\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-3yojemdt\\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\\setup.py'"'"'; __file__='"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-3yojemdt\\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Lenovo\AppData\Local\Temp\pip-wheel-giu0oeqj'
#        cwd: C:\Users\Lenovo\AppData\Local\Temp\pip-install-3yojemdt\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\
#   Complete output (85 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\config.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\data.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\download.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\gradient.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\model.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\optimizer.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\res_summarize.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\scorer.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\trainer.py -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\__init__.py -> build\lib.win-amd64-3.9\pkuseg
#   creating build\lib.win-amd64-3.9\pkuseg\dicts
#   copying pkuseg\dicts\__init__.py -> build\lib.win-amd64-3.9\pkuseg\dicts
#   creating build\lib.win-amd64-3.9\pkuseg\models
#   copying pkuseg\models\__init__.py -> build\lib.win-amd64-3.9\pkuseg\models
#   creating build\lib.win-amd64-3.9\pkuseg\postag
#   copying pkuseg\postag\model.py -> build\lib.win-amd64-3.9\pkuseg\postag
#   copying pkuseg\postag\__init__.py -> build\lib.win-amd64-3.9\pkuseg\postag
#   creating build\lib.win-amd64-3.9\pkuseg\models\default
#   copying pkuseg\models\default\__init__.py -> build\lib.win-amd64-3.9\pkuseg\models\default
#   copying pkuseg\feature_extractor.pyx -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\inference.pyx -> build\lib.win-amd64-3.9\pkuseg
#   copying pkuseg\dicts\default.pkl -> build\lib.win-amd64-3.9\pkuseg\dicts
#   copying pkuseg\postag\feature_extractor.pyx -> build\lib.win-amd64-3.9\pkuseg\postag
#   copying pkuseg\models\default\features.pkl -> build\lib.win-amd64-3.9\pkuseg\models\default
#   copying pkuseg\models\default\weights.npz -> build\lib.win-amd64-3.9\pkuseg\models\default
#   running build_ext
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Lenovo\AppData\Local\Temp\pip-install-3yojemdt\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\setup.py", line 63, in <module>
#       setup_package()
#     File "C:\Users\Lenovo\AppData\Local\Temp\pip-install-3yojemdt\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\setup.py", line 39, in setup_package
#       setuptools.setup(
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\__init__.py", line 155, in setup
#       return distutils.core.setup(**attrs)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#       return run_commands(dist)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#       dist.run_commands()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#       self.run_command(cmd)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\command\build_ext.py", line 79, in run
#       _build_ext.run(self)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\Cython\Distutils\old_build_ext.py", line 186, in run
#       _build_ext.build_ext.run(self)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 339, in run
#       self.build_extensions()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\Cython\Distutils\old_build_ext.py", line 195, in build_extensions
#       _build_ext.build_ext.build_extensions(self)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 448, in build_extensions
#       self._build_extensions_serial()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 473, in _build_extensions_serial
#       self.build_extension(ext)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\command\build_ext.py", line 202, in build_extension
#       _build_ext.build_extension(self, ext)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\command\build_ext.py", line 528, in build_extension
#       objects = self.compiler.compile(sources,
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 327, in compile
#       self.initialize()
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 224, in initialize
#       vc_env = _get_vc_env(plat_spec)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\msvc.py", line 316, in msvc14_get_vc_env
#       return _msvc14_get_vc_env(plat_spec)
#     File "D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\msvc.py", line 270, in _msvc14_get_vc_env
#       raise distutils.errors.DistutilsPlatformError(
#   setuptools._distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for pkuseg
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Anaconda3\envs\bishe\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-3yojemdt\\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\\setup.py'"'"'; __file__='"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-3yojemdt\\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Lenovo\AppData\Local\Temp\pip-record-5nti7mk7\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\Anaconda3\envs\bishe\Include\pkuseg'
#          cwd: C:\Users\Lenovo\AppData\Local\Temp\pip-install-3yojemdt\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\
#     Complete output (35 lines):
#     running install
#     D:\Anaconda3\envs\bishe\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\config.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\data.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\download.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\gradient.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\model.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\optimizer.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\res_summarize.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\scorer.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\trainer.py -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\__init__.py -> build\lib.win-amd64-3.9\pkuseg
#     creating build\lib.win-amd64-3.9\pkuseg\dicts
#     copying pkuseg\dicts\__init__.py -> build\lib.win-amd64-3.9\pkuseg\dicts
#     creating build\lib.win-amd64-3.9\pkuseg\models
#     copying pkuseg\models\__init__.py -> build\lib.win-amd64-3.9\pkuseg\models
#     creating build\lib.win-amd64-3.9\pkuseg\postag
#     copying pkuseg\postag\model.py -> build\lib.win-amd64-3.9\pkuseg\postag
#     copying pkuseg\postag\__init__.py -> build\lib.win-amd64-3.9\pkuseg\postag
#     creating build\lib.win-amd64-3.9\pkuseg\models\default
#     copying pkuseg\models\default\__init__.py -> build\lib.win-amd64-3.9\pkuseg\models\default
#     copying pkuseg\feature_extractor.pyx -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\inference.pyx -> build\lib.win-amd64-3.9\pkuseg
#     copying pkuseg\dicts\default.pkl -> build\lib.win-amd64-3.9\pkuseg\dicts
#     copying pkuseg\postag\feature_extractor.pyx -> build\lib.win-amd64-3.9\pkuseg\postag
#     copying pkuseg\models\default\features.pkl -> build\lib.win-amd64-3.9\pkuseg\models\default
#     copying pkuseg\models\default\weights.npz -> build\lib.win-amd64-3.9\pkuseg\models\default
#     running build_ext
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'D:\Anaconda3\envs\bishe\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-3yojemdt\\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\\setup.py'"'"'; __file__='"'"'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\pip-install-3yojemdt\\pkuseg_d13b37bcb5924150a8d0521b5b6ea476\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Lenovo\AppData\Local\Temp\pip-record-5nti7mk7\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\Anaconda3\envs\bishe\Include\pkuseg' Check the logs for full command output.

# %%
! pip install pip-review 
! pip-review --local --interactive --auto
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting pip-review
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/f6/ac/d9f4fb81808547277942135a6d64fff42aa0e526644e4c0fde18ef8955b5/pip_review-1.1.1-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: pip in d:\anaconda3\envs\crawl\lib\site-packages (from pip-review) (21.3.1)
# Requirement already satisfied: packaging in d:\anaconda3\envs\crawl\lib\site-packages (from pip-review) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\crawl\lib\site-packages (from packaging->pip-review) (3.0.7)
# Installing collected packages: pip-review
# Successfully installed pip-review-1.1.1
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3\envs\crawl\lib\site-packages (4.6.0)
# Collecting beautifulsoup4
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/69/bf/f0f194d3379d3f3347478bd267f754fc68c11cbf2fe302a6ab69447b1417/beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Requirement already satisfied: black in d:\anaconda3\envs\crawl\lib\site-packages (21.12b0)
# Collecting black
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/ed/c6/817f8f025f9ede44d8f028b9f9ee2a66abe6c605cfcb41029600cda1b205/black-22.1.0-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: blis in d:\anaconda3\envs\crawl\lib\site-packages (0.7.5)
# Collecting blis
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/fc/5c/fd45f71fe8953c7e593238bf946d52e230bc35712ee0612dcef3442ddf5f/blis-0.7.6-cp39-cp39-win_amd64.whl (6.6 MB)
# Requirement already satisfied: boto3 in d:\anaconda3\envs\crawl\lib\site-packages (1.20.41)
# Collecting boto3
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/24/46/c64d337b6b6cac7ce4d75ffb43223f974b8095aafaf974d847e9d09c2cc1/boto3-1.21.13-py3-none-any.whl (132 kB)
# Requirement already satisfied: botocore in d:\anaconda3\envs\crawl\lib\site-packages (1.23.41)
# Collecting botocore
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a5/34/567e87ece4328f51a6db92db8c58584aa9525603c86aff5eb77bfc713b41/botocore-1.24.13-py3-none-any.whl (8.6 MB)
# Requirement already satisfied: chardet in d:\anaconda3\envs\crawl\lib\site-packages (3.0.4)
# Collecting chardet
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/19/c7/fa589626997dd07bd87d9269342ccb74b1720384a4d739a1872bd84fbe68/chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: charset-normalizer in d:\anaconda3\envs\crawl\lib\site-packages (2.0.10)
# Collecting charset-normalizer
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/06/b3/24afc8868eba069a7f03650ac750a778862dc34941a4bebeb58706715726/charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied: click in d:\anaconda3\envs\crawl\lib\site-packages (8.0.3)
# Collecting click
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/4a/a8/0b2ced25639fb20cc1c9784de90a8c25f9504a7f18cd8b5397bd61696d7d/click-8.0.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: ConfigArgParse in d:\anaconda3\envs\crawl\lib\site-packages (0.15.1)
# Collecting ConfigArgParse
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/af/cb/2a6620656f029b7b49c302853b433fac2c8eda9cbb5a3bc70b186b1b5b90/ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# Requirement already satisfied: entrypoints in d:\anaconda3\envs\crawl\lib\site-packages (0.3)
# Collecting entrypoints
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/35/a8/365059bbcd4572cbc41de17fd5b682be5868b218c3c5479071865cab9078/entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: executing in d:\anaconda3\envs\crawl\lib\site-packages (0.8.2)
# Collecting executing
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/61/d8/ad89910dc1da01a24135cb3dce702c72a8172f7b8f896ac0c4c34bcaf323/executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: filelock in d:\anaconda3\envs\crawl\lib\site-packages (3.4.2)
# Collecting filelock
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/cd/f1/ba7dee3de0e9d3b8634d6fbaa5d0d407a7da64620305d147298b683e5c36/filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: fonttools in d:\anaconda3\envs\crawl\lib\site-packages (4.28.5)
# Collecting fonttools
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/1d/46/65a58d7b92905e2767000b3f6eb1d0301e9ed7d459d14461075c1db63349/fonttools-4.29.1-py3-none-any.whl (895 kB)
# Requirement already satisfied: gast in d:\anaconda3\envs\crawl\lib\site-packages (0.4.0)
# Collecting gast
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/5f/1c/b59500a88c5c3d9d601c5ca62b9df5e0964764472faed82a182958a922c5/gast-0.5.3-py3-none-any.whl (19 kB)
# Requirement already satisfied: gensim in d:\anaconda3\envs\crawl\lib\site-packages (3.6.0)
# Collecting gensim
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/09/26/a1b10ea80b4536b6a5d8b20c5ebd979b5e12cb30a7905d56d3f278444c2e/gensim-4.1.2-cp39-cp39-win_amd64.whl (24.0 MB)
# Requirement already satisfied: google-auth in d:\anaconda3\envs\crawl\lib\site-packages (2.4.0)
# Collecting google-auth
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/66/12/eb8e0254e84f47deb4bd65858aef26f93fb4786091442d6bd2e86a5843d3/google_auth-2.6.0-py2.py3-none-any.whl (156 kB)
# Requirement already satisfied: google-auth-oauthlib in d:\anaconda3\envs\crawl\lib\site-packages (0.4.6)
# Collecting google-auth-oauthlib
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/77/62/be9811606c4163068e8e5076864356881d3456b5c192997dee4e9a23acd6/google_auth_oauthlib-0.5.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio in d:\anaconda3\envs\crawl\lib\site-packages (1.43.0)
# Collecting grpcio
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/e2/29/059a2555a38dacd066a7a83fa7f735d1b6ff6b1cde3e62cdd09597dbe7be/grpcio-1.44.0-cp39-cp39-win_amd64.whl (3.4 MB)
# Requirement already satisfied: idna in d:\anaconda3\envs\crawl\lib\site-packages (2.6)
# Collecting idna
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/04/a2/d918dcd22354d8958fe113e1a3630137e0fc8b44859ade3063982eacd2a4/idna-3.3-py3-none-any.whl (61 kB)
# Requirement already satisfied: importlib-metadata in d:\anaconda3\envs\crawl\lib\site-packages (4.10.1)
# Collecting importlib-metadata
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/70/76/a44cce0f66f73ec6d5d8138f47a16cd3f9e57f4720bce7492d372ef5c74f/importlib_metadata-4.11.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: ipykernel in d:\anaconda3\envs\crawl\lib\site-packages (6.7.0)
# Collecting ipykernel
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/62/4e/1149519ad9e90b6903e5e4b73454cb02d2c0cd62ef2f21c9d93c752cdb5f/ipykernel-6.9.1-py3-none-any.whl (128 kB)
# Requirement already satisfied: ipython in d:\anaconda3\envs\crawl\lib\site-packages (8.0.0)
# Collecting ipython
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a0/fb/8a10b0d3293fab75ab4690925d3b790f1e4599b4b55eb3f4984ffc1753aa/ipython-8.1.1-py3-none-any.whl (750 kB)
# Requirement already satisfied: jieba in d:\anaconda3\envs\crawl\lib\site-packages (0.39)
# Collecting jieba
#   Using cached jieba-0.42.1-py3-none-any.whl
# Requirement already satisfied: jupyter-client in d:\anaconda3\envs\crawl\lib\site-packages (7.1.1)
# Collecting jupyter-client
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/56/a7/f4d3790ce7bb925d3ffe299244501a264f23ee7ec401914f7d788881ea31/jupyter_client-7.1.2-py3-none-any.whl (130 kB)
# Requirement already satisfied: jupyter-core in d:\anaconda3\envs\crawl\lib\site-packages (4.9.1)
# Collecting jupyter-core
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/60/7d/bee50351fe3ff6979e949b9c4c00c556a7a9732ba39b547d07d93450de23/jupyter_core-4.9.2-py3-none-any.whl (86 kB)
# Requirement already satisfied: keras in d:\anaconda3\envs\crawl\lib\site-packages (2.7.0)
# Collecting keras
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/4f/2f/eb9391bdcba2693cc8396f244bd3b4512bcd1123c2ea06f4dfcf50dc5ce9/keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: libclang in d:\anaconda3\envs\crawl\lib\site-packages (12.0.0)
# Collecting libclang
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/fa/09/98786c8eaae694c63a9305667d4e60faec3d5a3b7c32fdd30ce02c470cab/libclang-13.0.0-py2.py3-none-win_amd64.whl (13.9 MB)
# Requirement already satisfied: lxml in d:\anaconda3\envs\crawl\lib\site-packages (4.7.1)
# Collecting lxml
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/77/58/a056a0876c5befaf9a9fdfb3ef67d7500cf85012b87c7358a4c130c97170/lxml-4.8.0-cp39-cp39-win_amd64.whl (3.6 MB)
# Requirement already satisfied: MarkupSafe in d:\anaconda3\envs\crawl\lib\site-packages (2.0.1)
# Collecting MarkupSafe
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/8d/b1/584a204372c41d6b56dce941b3cdc06bc7a325ad790a77ac50d7893da404/MarkupSafe-2.1.0-cp39-cp39-win_amd64.whl (16 kB)
# Requirement already satisfied: networkx in d:\anaconda3\envs\crawl\lib\site-packages (2.6.3)
# Collecting networkx
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f6/34/4913f651b8e178dde5abcf8d62495e4dcd0757a9a6840f1b1f7a290afaea/networkx-2.7.1-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: nltk in d:\anaconda3\envs\crawl\lib\site-packages (3.6.7)
# Collecting nltk
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/43/0b/8298798bc5a9a007b7cae3f846a3d9a325953e0f9c238affa478b4d59324/nltk-3.7-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: numpy in d:\anaconda3\envs\crawl\lib\site-packages (1.22.0)
# Collecting numpy
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/4b/23/140ec5a509d992fe39db17200e96c00fd29603c1531ce633ef93dbad5e9e/numpy-1.22.2-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: oauthlib in d:\anaconda3\envs\crawl\lib\site-packages (3.1.1)
# Collecting oauthlib
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/1d/46/5ee2475e1b46a26ca0fa10d3c1d479577fde6ee289f8c6aa6d7ec33e31fd/oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: pandas in d:\anaconda3\envs\crawl\lib\site-packages (1.3.5)
# Collecting pandas
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3b/81/73396f8b40cb02887116af3b45f34c6a3a434682a1026686ad48d51900eb/pandas-1.4.1-cp39-cp39-win_amd64.whl (10.5 MB)
# Requirement already satisfied: Pillow in d:\anaconda3\envs\crawl\lib\site-packages (9.0.0)
# Collecting Pillow
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/6c/96/e905dd0ffa0f9599187d57eba08bc9b911817f35a4dfd6345bceb991261d/Pillow-9.0.1-cp39-cp39-win_amd64.whl (3.2 MB)
# Requirement already satisfied: pip in d:\anaconda3\envs\crawl\lib\site-packages (21.3.1)
# Collecting pip
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/6a/df/a6ef77a6574781a668791419ffe366c8acd1c3cf4709d210cb53cd5ce1c2/pip-22.0.3-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: platformdirs in d:\anaconda3\envs\crawl\lib\site-packages (2.3.0)
# Collecting platformdirs
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/de/de/d8b9da351517c3dece273224522d4714cfdb9a89e2e6f7f7f054a340cc2b/platformdirs-2.5.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: prompt-toolkit in d:\anaconda3\envs\crawl\lib\site-packages (3.0.24)
# Collecting prompt-toolkit
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/00/e4/beb2fad0bec554a011b321d0f6b99981f9171c0b05d03a6948e45ac8a5be/prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
# Requirement already satisfied: protobuf in d:\anaconda3\envs\crawl\lib\site-packages (3.19.3)
# Collecting protobuf
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/ef/09/d36ab17b165f3bd942c44c025a19d92d20b25ef550c457d1fe8a65b71fa7/protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# Requirement already satisfied: pure-eval in d:\anaconda3\envs\crawl\lib\site-packages (0.2.1)
# Collecting pure-eval
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2b/27/77f9d5684e6bce929f5cfe18d6cfbe5133013c06cb2fbf5933670e60761d/pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: pyarrow in d:\anaconda3\envs\crawl\lib\site-packages (6.0.1)
# Collecting pyarrow
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e9/36/cee35cc78af18535ef5218ffaf3505a84c519d5b66bebc062175bf3c9c66/pyarrow-7.0.0-cp39-cp39-win_amd64.whl (16.1 MB)
# Requirement already satisfied: pydantic in d:\anaconda3\envs\crawl\lib\site-packages (1.8.2)
# Collecting pydantic
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ab/75/d1b75966886315bb269060201259cfc2ff0481a69e06df907363c5420bed/pydantic-1.9.0-cp39-cp39-win_amd64.whl (2.1 MB)
# Requirement already satisfied: pymongo in d:\anaconda3\envs\crawl\lib\site-packages (3.6.0)
# Collecting pymongo
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3d/bf/677a23e8385541ed48c02d015629c26683b088f43f2e45e3357481e9a620/pymongo-4.0.2-cp39-cp39-win_amd64.whl (350 kB)
# Requirement already satisfied: regex in d:\anaconda3\envs\crawl\lib\site-packages (2022.1.18)
# Collecting regex
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/05/6f/efa5681319f5ed7a7d5372f5d44c86fff9c759588075b8406fc32a7a5b9b/regex-2022.3.2-cp39-cp39-win_amd64.whl (274 kB)
# Requirement already satisfied: requests-oauthlib in d:\anaconda3\envs\crawl\lib\site-packages (1.3.0)
# Collecting requests-oauthlib
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/6f/bb/5deac77a9af870143c684ab46a7934038a53eb4aa975bc0687ed6ca2c610/requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: s3transfer in d:\anaconda3\envs\crawl\lib\site-packages (0.5.0)
# Collecting s3transfer
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7b/9c/f51775ebe7df5a7aa4e7c79ed671bde94e154bd968aca8d65bb24aba0c8c/s3transfer-0.5.2-py3-none-any.whl (79 kB)
# Requirement already satisfied: scipy in d:\anaconda3\envs\crawl\lib\site-packages (1.7.3)
# Collecting scipy
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/5d/43/79af04bf5eef99cedb068148a1a0bb04567d958c872c85b02c8bc65021e7/scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
# Requirement already satisfied: setuptools in d:\anaconda3\envs\crawl\lib\site-packages (59.5.0)
# Collecting setuptools
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3b/02/8d4d27b1cacaac2d129a27d17a22d92a2a5eedcb7817d4ed8ab0d4daf5c4/setuptools-60.9.3-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: spacy in d:\anaconda3\envs\crawl\lib\site-packages (3.2.1)
# Collecting spacy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/20/26/dbb10444fe3ae34fb440c4d69cf9cd9696518aa723bd93d56b9553c267e2/spacy-3.2.3-cp39-cp39-win_amd64.whl (11.3 MB)
# Requirement already satisfied: spacy-legacy in d:\anaconda3\envs\crawl\lib\site-packages (3.0.8)
# Collecting spacy-legacy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/79/44/7c56d123f40a9186e155db4832cb5c5086b94d9871ac421a5115e3a4d537/spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: SQLAlchemy in d:\anaconda3\envs\crawl\lib\site-packages (1.4.29)
# Collecting SQLAlchemy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6b/fc/f760cae409ad06787fb1f6d0ebd97ce67881fbf14ee5b377ef4ed4ab4aa3/SQLAlchemy-1.4.31-cp39-cp39-win_amd64.whl (1.6 MB)
# Requirement already satisfied: stack-data in d:\anaconda3\envs\crawl\lib\site-packages (0.1.3)
# Collecting stack-data
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/6b/25/9a454b432df53ffbbb4f03198c3347f393c34f4de07fb652563bdbdf91e8/stack_data-0.2.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: tensorboard in d:\anaconda3\envs\crawl\lib\site-packages (1.15.0)
# Collecting tensorboard
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/f7/fd/67c61276de025801cfa8a1b9af2d7c577e7f27c17b6bff2baca20bf03543/tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: tensorflow in d:\anaconda3\envs\crawl\lib\site-packages (2.7.0)
# Collecting tensorflow
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/dd/0b/6fd33732d436a6735094b6e44359e13c10901e71aeaf348ff7c9e4ee08c9/tensorflow-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
# Requirement already satisfied: tensorflow-estimator in d:\anaconda3\envs\crawl\lib\site-packages (2.7.0)
# Collecting tensorflow-estimator
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/4e/42/cefc351e0e428ca9c460bfbd994ec9f01e5d8bd34f88c65a7ea807ecd67a/tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem in d:\anaconda3\envs\crawl\lib\site-packages (0.23.1)
# Collecting tensorflow-io-gcs-filesystem
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/c6/74/179375d2fdc00de015f0f8e622a16fcd2856e5536636a343c1c364138315/tensorflow_io_gcs_filesystem-0.24.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: threadpoolctl in d:\anaconda3\envs\crawl\lib\site-packages (3.0.0)
# Collecting threadpoolctl
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/61/cf/6e354304bcb9c6413c4e02a747b600061c21d38ba51e7e544ac7bc66aecc/threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: tokenizers in d:\anaconda3\envs\crawl\lib\site-packages (0.11.4)
# Collecting tokenizers
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/77/a5/2f6f2c25fb9f3a237aa326a8f3b3fe7a7aae6331136325cf2418dcbc9b89/tokenizers-0.11.6-cp39-cp39-win_amd64.whl (3.2 MB)
# Requirement already satisfied: tomli in d:\anaconda3\envs\crawl\lib\site-packages (1.2.2)
# Collecting tomli
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/97/75/10a9ebee3fd790d20926a90a2547f0bf78f371b2f13aa822c759680ca7b9/tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: torch in d:\anaconda3\envs\crawl\lib\site-packages (1.10.0)
# Collecting torch
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/82/49/cb675c5b70a081f39a2b09d0b4d98a2b14f08d895b3439fe3c0c48163018/torch-1.10.2-cp39-cp39-win_amd64.whl (226.5 MB)
# Requirement already satisfied: torchaudio in d:\anaconda3\envs\crawl\lib\site-packages (0.10.1)
# Collecting torchaudio
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/d0/c9/8fcdb83e97fd43b1946ef04a99e3968c3e26d9a4249670c2f609051eac46/torchaudio-0.10.2-cp39-cp39-win_amd64.whl (341 kB)
# Requirement already satisfied: torchtext in d:\anaconda3\envs\crawl\lib\site-packages (0.11.0)
# Collecting torchtext
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/13/76/e09e38a9d1368497ccf49df6e0a3cd45b52abd7d8a3ab5219fce1cac23d1/torchtext-0.11.2-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: torchvision in d:\anaconda3\envs\crawl\lib\site-packages (0.11.2)
# Collecting torchvision
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/8b/68/5a976d601c11f527cb278dbd510521e3d6e192d7c5fd60471e64d1c84c25/torchvision-0.11.3-cp39-cp39-win_amd64.whl (947 kB)
# Requirement already satisfied: tqdm in d:\anaconda3\envs\crawl\lib\site-packages (4.38.0)
# Collecting tqdm
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/81/1c/93a2b77b97cdba15a59c3d2d03e53d3292158d1106d37f579069abd90ece/tqdm-4.63.0-py2.py3-none-any.whl (76 kB)
# Requirement already satisfied: transformers in d:\anaconda3\envs\crawl\lib\site-packages (4.16.1)
# Collecting transformers
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a0/11/07cea2439c82726ee05575472e5b09c3b6eeac7e32eef1a736ad3646a8f0/transformers-4.17.0-py3-none-any.whl (3.8 MB)
# Requirement already satisfied: tweepy in d:\anaconda3\envs\crawl\lib\site-packages (4.5.0)
# Collecting tweepy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/02/cf/fab85d975d5da397bae3b855d9bccde712a8ebc3a1d04c2e7b670a9334b7/tweepy-4.6.0-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: typed-ast in d:\anaconda3\envs\crawl\lib\site-packages (1.5.1)
# Collecting typed-ast
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/82/8d/01126a8bbba6ad956ffd7006d8c3ff704e61623e9ffecd3a68d86ea19852/typed_ast-1.5.2-cp39-cp39-win_amd64.whl (165 kB)
# Requirement already satisfied: typing_extensions in d:\anaconda3\envs\crawl\lib\site-packages (4.0.1)
# Collecting typing_extensions
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/45/6b/44f7f8f1e110027cf88956b59f2fad776cca7e1704396d043f89effd3a0e/typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: Werkzeug in d:\anaconda3\envs\crawl\lib\site-packages (2.0.2)
# Collecting Werkzeug
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/f4/f3/22afbdb20cc4654b10c98043414a14057cd27fdba9d4ae61cea596000ba2/Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Requirement already satisfied: yfinance in d:\anaconda3\envs\crawl\lib\site-packages (0.1.69)
# Collecting yfinance
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a1/b5/bf3bf6adf9acdd18ac15f93e2d42b7a9a468f8cb70144e316980d9d9dd61/yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Collecting soupsieve>1.2
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/72/a6/fd01694427f1c3fcadfdc5f1de901b813b9ac756f0806ef470cfed1de281/soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: mypy-extensions>=0.4.3 in d:\anaconda3\envs\crawl\lib\site-packages (from black) (0.4.3)
# Requirement already satisfied: pathspec>=0.9.0 in d:\anaconda3\envs\crawl\lib\site-packages (from black) (0.9.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in d:\anaconda3\envs\crawl\lib\site-packages (from boto3) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\anaconda3\envs\crawl\lib\site-packages (from botocore) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in d:\anaconda3\envs\crawl\lib\site-packages (from botocore) (1.26.8)
# Requirement already satisfied: colorama in d:\anaconda3\envs\crawl\lib\site-packages (from click) (0.4.4)
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda3\envs\crawl\lib\site-packages (from gensim) (5.2.1)
# Collecting Cython==0.29.23
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/87/61/2724e1a7e68672579990a2a841919470d93c21e9a1a38f27ce839090a385/Cython-0.29.23-cp39-cp39-win_amd64.whl (1.7 MB)
# Requirement already satisfied: six>=1.9.0 in d:\anaconda3\envs\crawl\lib\site-packages (from google-auth) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda3\envs\crawl\lib\site-packages (from google-auth) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\envs\crawl\lib\site-packages (from google-auth) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda3\envs\crawl\lib\site-packages (from google-auth) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\envs\crawl\lib\site-packages (from importlib-metadata) (3.7.0)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in d:\anaconda3\envs\crawl\lib\site-packages (from ipykernel) (5.1.1)
# Requirement already satisfied: nest-asyncio in d:\anaconda3\envs\crawl\lib\site-packages (from ipykernel) (1.5.4)
# Requirement already satisfied: tornado<7.0,>=4.2 in d:\anaconda3\envs\crawl\lib\site-packages (from ipykernel) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in d:\anaconda3\envs\crawl\lib\site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in d:\anaconda3\envs\crawl\lib\site-packages (from ipykernel) (1.5.1)
# Requirement already satisfied: backcall in d:\anaconda3\envs\crawl\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: pickleshare in d:\anaconda3\envs\crawl\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3\envs\crawl\lib\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda3\envs\crawl\lib\site-packages (from ipython) (2.11.2)
# Requirement already satisfied: decorator in d:\anaconda3\envs\crawl\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: pyzmq>=13 in d:\anaconda3\envs\crawl\lib\site-packages (from jupyter-client) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda3\envs\crawl\lib\site-packages (from jupyter-core) (303)
# Requirement already satisfied: joblib in d:\anaconda3\envs\crawl\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\crawl\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: wcwidth in d:\anaconda3\envs\crawl\lib\site-packages (from prompt-toolkit) (0.2.5)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda3\envs\crawl\lib\site-packages (from requests-oauthlib) (2.27.1)
# Requirement already satisfied: pathy>=0.3.5 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (1.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: jinja2 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (3.0.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (1.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (8.0.13)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in d:\anaconda3\envs\crawl\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda3\envs\crawl\lib\site-packages (from SQLAlchemy) (1.1.2)
# Requirement already satisfied: asttokens in d:\anaconda3\envs\crawl\lib\site-packages (from stack-data) (2.0.5)
# Requirement already satisfied: absl-py>=0.4 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorboard) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorboard) (0.37.1)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a7/f1/f89e097f377b163856076f167baf149b010df3bbf425d2c06276048e2051/tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: flatbuffers>=1.12 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda3\envs\crawl\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in d:\anaconda3\envs\crawl\lib\site-packages (from transformers) (0.4.0)
# Requirement already satisfied: sacremoses in d:\anaconda3\envs\crawl\lib\site-packages (from transformers) (0.0.47)
# Requirement already satisfied: pyyaml>=5.1 in d:\anaconda3\envs\crawl\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: multitasking>=0.0.7 in d:\anaconda3\envs\crawl\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda3\envs\crawl\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\crawl\lib\site-packages (from packaging>=20.0->spacy) (3.0.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda3\envs\crawl\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\crawl\lib\site-packages (from requests>=2.0.0->requests-oauthlib) (2021.10.8)
# Installing collected packages: idna, charset-normalizer, oauthlib, typing-extensions, requests-oauthlib, pure-eval, numpy, importlib-metadata, google-auth, executing, click, Werkzeug, tqdm, stack-data, setuptools, regex, protobuf, prompt-toolkit, MarkupSafe, jupyter-core, grpcio, filelock, entrypoints, botocore, blis, torch, tomli, tokenizers, tf-estimator-nightly, tensorflow-io-gcs-filesystem, tensorboard, spacy-legacy, soupsieve, scipy, s3transfer, platformdirs, Pillow, pandas, lxml, libclang, keras, jupyter-client, ipython, gast, Cython, yfinance, typed-ast, tweepy, transformers, torchvision, torchtext, torchaudio, threadpoolctl, tensorflow-estimator, tensorflow, SQLAlchemy, spacy, pymongo, pyarrow, pip, nltk, networkx, jieba, ipykernel, gensim, fonttools, ConfigArgParse, chardet, boto3, black, beautifulsoup4
#   Attempting uninstall: idna
#     Found existing installation: idna 2.6
#     Uninstalling idna-2.6:
#       Successfully uninstalled idna-2.6
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.10
#     Uninstalling charset-normalizer-2.0.10:
#       Successfully uninstalled charset-normalizer-2.0.10
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.1.1
#     Uninstalling oauthlib-3.1.1:
#       Successfully uninstalled oauthlib-3.1.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.0.1
#     Uninstalling typing-extensions-4.0.1:
#       Successfully uninstalled typing-extensions-4.0.1
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.3.0
#     Uninstalling requests-oauthlib-1.3.0:
#       Successfully uninstalled requests-oauthlib-1.3.0
#   Attempting uninstall: pure-eval
#     Found existing installation: pure-eval 0.2.1
#     Uninstalling pure-eval-0.2.1:
#       Successfully uninstalled pure-eval-0.2.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.0
#     Uninstalling numpy-1.22.0:
#       Successfully uninstalled numpy-1.22.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.10.1
#     Uninstalling importlib-metadata-4.10.1:
#       Successfully uninstalled importlib-metadata-4.10.1
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.4.0
#     Uninstalling google-auth-2.4.0:
#       Successfully uninstalled google-auth-2.4.0
#   Attempting uninstall: executing
#     Found existing installation: executing 0.8.2
#     Uninstalling executing-0.8.2:
#       Successfully uninstalled executing-0.8.2
#   Attempting uninstall: click
#     Found existing installation: click 8.0.3
#     Uninstalling click-8.0.3:
#       Successfully uninstalled click-8.0.3
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.2
#     Uninstalling Werkzeug-2.0.2:
#       Successfully uninstalled Werkzeug-2.0.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.38.0
#     Uninstalling tqdm-4.38.0:
#       Successfully uninstalled tqdm-4.38.0
#   Attempting uninstall: stack-data
#     Found existing installation: stack-data 0.1.3
#     Uninstalling stack-data-0.1.3:
#       Successfully uninstalled stack-data-0.1.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.5.0
#     Uninstalling setuptools-59.5.0:
#       Successfully uninstalled setuptools-59.5.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.1.18
#     Uninstalling regex-2022.1.18:
#       Successfully uninstalled regex-2022.1.18
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.3
#     Uninstalling protobuf-3.19.3:
#       Successfully uninstalled protobuf-3.19.3
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.24
#     Uninstalling prompt-toolkit-3.0.24:
#       Successfully uninstalled prompt-toolkit-3.0.24
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.9.1
#     Uninstalling jupyter-core-4.9.1:
#       Successfully uninstalled jupyter-core-4.9.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.43.0
#     Uninstalling grpcio-1.43.0:
#       Successfully uninstalled grpcio-1.43.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.4.2
#     Uninstalling filelock-3.4.2:
#       Successfully uninstalled filelock-3.4.2
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.3
#     Uninstalling entrypoints-0.3:
#       Successfully uninstalled entrypoints-0.3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.23.41
#     Uninstalling botocore-1.23.41:
#       Successfully uninstalled botocore-1.23.41
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.5
#     Uninstalling blis-0.7.5:
#       Successfully uninstalled blis-0.7.5
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0
#     Uninstalling torch-1.10.0:
#       Successfully uninstalled torch-1.10.0
#   Attempting uninstall: tomli
#     Found existing installation: tomli 1.2.2
#     Uninstalling tomli-1.2.2:
#       Successfully uninstalled tomli-1.2.2
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.11.4
#     Uninstalling tokenizers-0.11.4:
#       Successfully uninstalled tokenizers-0.11.4
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.23.1
#     Uninstalling tensorflow-io-gcs-filesystem-0.23.1:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.23.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Attempting uninstall: spacy-legacy
#     Found existing installation: spacy-legacy 3.0.8
#     Uninstalling spacy-legacy-3.0.8:
#       Successfully uninstalled spacy-legacy-3.0.8
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.5.0
#     Uninstalling s3transfer-0.5.0:
#       Successfully uninstalled s3transfer-0.5.0
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 2.3.0
#     Uninstalling platformdirs-2.3.0:
#       Successfully uninstalled platformdirs-2.3.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.0.0
#     Uninstalling Pillow-9.0.0:
#       Successfully uninstalled Pillow-9.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.7.1
#     Uninstalling lxml-4.7.1:
#       Successfully uninstalled lxml-4.7.1
#   Attempting uninstall: libclang
#     Found existing installation: libclang 12.0.0
#     Uninstalling libclang-12.0.0:
#       Successfully uninstalled libclang-12.0.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 7.1.1
#     Uninstalling jupyter-client-7.1.1:
#       Successfully uninstalled jupyter-client-7.1.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.0.0
#     Uninstalling ipython-8.0.0:
#       Successfully uninstalled ipython-8.0.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.1.69
#     Uninstalling yfinance-0.1.69:
#       Successfully uninstalled yfinance-0.1.69
#   Attempting uninstall: typed-ast
#     Found existing installation: typed-ast 1.5.1
#     Uninstalling typed-ast-1.5.1:
#       Successfully uninstalled typed-ast-1.5.1
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 4.5.0
#     Uninstalling tweepy-4.5.0:
#       Successfully uninstalled tweepy-4.5.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.16.1
#     Uninstalling transformers-4.16.1:
#       Successfully uninstalled transformers-4.16.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.2
#     Uninstalling torchvision-0.11.2:
#       Successfully uninstalled torchvision-0.11.2
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.11.0
#     Uninstalling torchtext-0.11.0:
#       Successfully uninstalled torchtext-0.11.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.10.1
#     Uninstalling torchaudio-0.10.1:
#       Successfully uninstalled torchaudio-0.10.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.0.0
#     Uninstalling threadpoolctl-3.0.0:
#       Successfully uninstalled threadpoolctl-3.0.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 1.4.29
#     Uninstalling SQLAlchemy-1.4.29:
#       Successfully uninstalled SQLAlchemy-1.4.29
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.1
#     Uninstalling spacy-3.2.1:
#       Successfully uninstalled spacy-3.2.1
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 3.6.0
#     Uninstalling pymongo-3.6.0:
#       Successfully uninstalled pymongo-3.6.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 6.0.1
#     Uninstalling pyarrow-6.0.1:
#       Successfully uninstalled pyarrow-6.0.1
#   Attempting uninstall: pip
#     Found existing installation: pip 21.3.1
#     Uninstalling pip-21.3.1:
#       Successfully uninstalled pip-21.3.1
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.6.7
#     Uninstalling nltk-3.6.7:
#       Successfully uninstalled nltk-3.6.7
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
#   Attempting uninstall: jieba
#     Found existing installation: jieba 0.39
#     Uninstalling jieba-0.39:
#       Successfully uninstalled jieba-0.39
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.7.0
#     Uninstalling ipykernel-6.7.0:
#       Successfully uninstalled ipykernel-6.7.0
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.28.5
#     Uninstalling fonttools-4.28.5:
#       Successfully uninstalled fonttools-4.28.5
#   Attempting uninstall: ConfigArgParse
#     Found existing installation: ConfigArgParse 0.15.1
#     Uninstalling ConfigArgParse-0.15.1:
#       Successfully uninstalled ConfigArgParse-0.15.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 3.0.4
#     Uninstalling chardet-3.0.4:
#       Successfully uninstalled chardet-3.0.4
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.20.41
#     Uninstalling boto3-1.20.41:
#       Successfully uninstalled boto3-1.20.41
#   Attempting uninstall: black
#     Found existing installation: black 21.12b0
#     Uninstalling black-21.12b0:
#       Successfully uninstalled black-21.12b0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.0
#     Uninstalling beautifulsoup4-4.6.0:
#       Successfully uninstalled beautifulsoup4-4.6.0
# Successfully installed ConfigArgParse-1.5.3 Cython-0.29.23 MarkupSafe-2.1.0 Pillow-9.0.1 SQLAlchemy-1.4.31 Werkzeug-2.0.3 beautifulsoup4-4.10.0 black-22.1.0 blis-0.7.6 boto3-1.21.13 botocore-1.24.13 chardet-4.0.0 charset-normalizer-2.0.12 click-8.0.4 entrypoints-0.4 executing-0.8.3 filelock-3.6.0 fonttools-4.29.1 gast-0.5.3 gensim-4.1.2 google-auth-2.6.0 grpcio-1.44.0 idna-3.3 importlib-metadata-4.11.2 ipykernel-6.9.1 ipython-8.1.1 jieba-0.42.1 jupyter-client-7.1.2 jupyter-core-4.9.2 keras-2.8.0 libclang-13.0.0 lxml-4.8.0 networkx-2.7.1 nltk-3.7 numpy-1.22.2 oauthlib-3.2.0 pandas-1.4.1 pip-22.0.3 platformdirs-2.5.1 prompt-toolkit-3.0.28 protobuf-3.19.4 pure-eval-0.2.2 pyarrow-7.0.0 pymongo-4.0.2 regex-2022.3.2 requests-oauthlib-1.3.1 s3transfer-0.5.2 scipy-1.8.0 setuptools-60.9.3 soupsieve-2.3.1 spacy-3.2.3 spacy-legacy-3.0.9 stack-data-0.2.0 tensorboard-2.8.0 tensorflow-2.8.0 tensorflow-estimator-2.8.0 tensorflow-io-gcs-filesystem-0.24.0 tf-estimator-nightly-2.8.0.dev2021122109 threadpoolctl-3.1.0 tokenizers-0.11.6 tomli-2.0.1 torch-1.10.2 torchaudio-0.10.2 torchtext-0.11.2 torchvision-0.11.3 tqdm-4.63.0 transformers-4.17.0 tweepy-4.6.0 typed-ast-1.5.2 typing-extensions-4.1.1 yfinance-0.1.70

# %%
! pip install gensim
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting gensim
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/09/26/a1b10ea80b4536b6a5d8b20c5ebd979b5e12cb30a7905d56d3f278444c2e/gensim-4.1.2-cp39-cp39-win_amd64.whl (24.0 MB)
# Collecting smart-open>=1.8.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/cd/11/05f68ea934c24ade38e95ac30a38407767787c4e3db1776eae4886ad8c95/smart_open-5.2.1-py3-none-any.whl (58 kB)
# Requirement already satisfied: scipy>=0.18.1 in d:\anaconda3\envs\bishe\lib\site-packages (from gensim) (1.8.0)
# Requirement already satisfied: numpy>=1.17.0 in d:\anaconda3\envs\bishe\lib\site-packages (from gensim) (1.22.2)
# Collecting Cython==0.29.23
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/87/61/2724e1a7e68672579990a2a841919470d93c21e9a1a38f27ce839090a385/Cython-0.29.23-cp39-cp39-win_amd64.whl (1.7 MB)
# Installing collected packages: smart-open, Cython, gensim
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.28
#     Uninstalling Cython-0.29.28:
#       Successfully uninstalled Cython-0.29.28
# Successfully installed Cython-0.29.23 gensim-4.1.2 smart-open-5.2.1

# %%
! pip install word2vec
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting word2vec
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/11/9e/dc6d96578191b6167cb1ea4a3fe3edeed0dce54d3db21ada013b2b407d65/word2vec-0.11.1.tar.gz (42 kB)
#      ---------------------------------------- 42.3/42.3 KB 2.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: joblib in d:\anaconda3\envs\bishe\lib\site-packages (from word2vec) (1.1.0)
# Requirement already satisfied: numpy>=1.9.2 in d:\anaconda3\envs\bishe\lib\site-packages (from word2vec) (1.22.2)
# Building wheels for collected packages: word2vec
#   Building wheel for word2vec (pyproject.toml): started
#   Building wheel for word2vec (pyproject.toml): finished with status 'done'
#   Created wheel for word2vec: filename=word2vec-0.11.1-py2.py3-none-any.whl size=179601 sha256=fb0df125080affbc72c45bc76444731307ca34ca9bf96b799cb999726a827190
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\8f\e6\bb\5d7e1bea7962c23d18f9c90b69b7fbd6a5c15696ed6cd371bd
# Successfully built word2vec
# Installing collected packages: word2vec
# Successfully installed word2vec-0.11.1

# %%
! pip install torchinfo
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting torchinfo
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/19/da/9d0d2cf6094c56dc9f75e9c2beb065443efc5f998bcf485e128273525ee7/torchinfo-1.6.3-py3-none-any.whl (20 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.6.3

# %%
! pip install xgboost
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting xgboost
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/97/ef/05245964011e4fc5aa0d86e2285a41de122ee1c30d69df05ecfd594bd608/xgboost-1.5.2-py3-none-win_amd64.whl (106.6 MB)
#      -------------------------------------- 106.6/106.6 MB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in d:\anaconda3\envs\bishe\lib\site-packages (from xgboost) (1.8.0)
# Requirement already satisfied: numpy in d:\anaconda3\envs\bishe\lib\site-packages (from xgboost) (1.22.2)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.5.2

# %%
! pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       1.0.0
# asttokens                     2.0.5
# astunparse                    1.6.3
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.10.0
# black                         22.1.0
# bs4                           0.0.1
# cachetools                    5.0.0
# certifi                       2021.10.8
# charset-normalizer            2.0.12
# click                         8.0.4
# colorama                      0.4.4
# cycler                        0.11.0
# Cython                        0.29.23
# dataclasses                   0.8
# debugpy                       1.5.1
# decorator                     5.1.1
# dgl                           0.6.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# filelock                      3.6.0
# flatbuffers                   2.0
# fonttools                     4.29.1
# gast                          0.5.3
# gensim                        4.1.2
# google-auth                   2.6.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# graphviz                      0.19.1
# grpcio                        1.44.0
# h5py                          3.6.0
# hanlp                         2.1.0b15
# hanlp-common                  0.0.14
# hanlp-downloader              0.0.25
# hanlp-restful                 0.0.9
# hanlp-trie                    0.0.4
# huggingface-hub               0.4.0
# idna                          3.3
# imageio                       2.16.1
# importlib-metadata            4.11.2
# interchange                   2021.0.4
# ipykernel                     6.9.1
# ipython                       8.1.1
# jedi                          0.18.1
# jieba                         0.42.1
# joblib                        1.1.0
# jupyter-client                7.1.2
# jupyter-core                  4.9.2
# keras                         2.8.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.2
# libclang                      13.0.0
# lxml                          4.8.0
# Markdown                      3.3.6
# matplotlib                    3.5.1
# matplotlib-inline             0.1.3
# monotonic                     1.6
# mplfinance                    0.12.8b9
# mypy-extensions               0.4.3
# nest-asyncio                  1.5.4
# networkx                      2.7.1
# nltk                          3.7
# numpy                         1.22.2
# oauthlib                      3.2.0
# objgraph                      3.5.0
# openpyxl                      3.0.9
# opt-einsum                    3.3.0
# packaging                     21.3
# paddlepaddle-tiny             1.6.1
# pandas                        1.4.1
# pansi                         2020.7.3
# parso                         0.8.3
# pathspec                      0.9.0
# patsy                         0.5.2
# phrasetree                    0.0.8
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           22.0.3
# pip-review                    1.1.1
# platformdirs                  2.5.1
# pmdarima                      1.8.5
# prompt-toolkit                3.0.28
# protobuf                      3.19.4
# pure-eval                     0.2.2
# py2neo                        2021.2.3
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# Pygments                      2.11.2
# pynvml                        11.4.1
# pyparsing                     3.0.7
# python-dateutil               2.8.2
# pytz                          2021.3
# pywin32                       303
# PyYAML                        6.0
# pyzmq                         22.3.0
# regex                         2022.3.2
# requests                      2.27.1
# requests-oauthlib             1.3.1
# rsa                           4.8
# sacremoses                    0.0.47
# scikit-learn                  1.0.2
# scipy                         1.8.0
# seaborn                       0.11.2
# setuptools                    60.9.3
# simplejson                    3.17.6
# six                           1.16.0
# smart-open                    5.2.1
# soupsieve                     2.3.1
# stack-data                    0.2.0
# statsmodels                   0.13.2
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorboardX                  2.5
# tensorflow                    2.8.0
# tensorflow-estimator          2.8.0
# tensorflow-io-gcs-filesystem  0.24.0
# termcolor                     1.1.0
# tf-estimator-nightly          2.8.0.dev2021122109
# threadpoolctl                 3.1.0
# tokenizers                    0.11.6
# tomli                         2.0.1
# toposort                      1.7
# torch                         1.10.2
# torchaudio                    0.10.2
# torchinfo                     1.6.3
# torchsummary                  1.5.1
# torchtext                     0.11.2
# torchvision                   0.11.3
# tornado                       6.1
# tqdm                          4.63.0
# traitlets                     5.1.1
# transformers                  4.17.0
# tushare                       1.2.84
# typed-ast                     1.5.2
# typing_extensions             4.1.1
# urllib3                       1.26.8
# wcwidth                       0.2.5
# websocket-client              0.57.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# word2vec                      0.11.1
# wordcloud                     1.8.1
# wrapt                         1.13.3
# xgboost                       1.5.2
# yapf                          0.32.0
# zhon                          1.1.5
# zipp                          3.7.0

# %%
! pip install pretty_errors
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting pretty_errors
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6d/8e/2df7467a15eae40e26c476683962fdb810cd1b36676603e2f139b4abbeaf/pretty_errors-1.2.25-py3-none-any.whl (17 kB)
# Requirement already satisfied: colorama in d:\anaconda3\envs\bishe\lib\site-packages (from pretty_errors) (0.4.4)
# Installing collected packages: pretty_errors
# Successfully installed pretty_errors-1.2.25
